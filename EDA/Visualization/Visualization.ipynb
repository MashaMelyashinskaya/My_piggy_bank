# %% [markdown]
# ### Визуал - важная часть аналитической работы.
#
# Задача - показать мои навыки в этой области. Поэтому здесь:
# - приклеплены примеры моих чартов и дашбордов из Superset, DataLens, Redash
# - также прикреплен пример отчета из телеграм-бота (куда Airflow регулярно их отправляет)

# %% [markdown]
# Итак, что я умею?
# 1. Начинать работу с дашбордом с определения бизнес-целей и выстраивать его структуру по четкому алгоритму
# 2. Проверять данные, которые использую
# 3. Строить чарты для оценки базовых метрик
# 4. Подбирать верный тип диаграммы
# 5. Делать визуал, отражающий реальное изменение метрик
# 6. Проводить глубокую аналитику с помощью чартов
# 7. Подбирать цветовое решениe с учетом знаний о цвете
# 8. И наконец, собирать из базовых чартов информативные, но не перегруженные дашборды
# 9. Также умею настраивать отправку отчетов в телеграм-бот с помощью Airflow

# %% [markdown]
# #### <u>1. Начинать работу с дашбордом с определения бизнес-целей и выстраивать его структуру по четкому алгоритму</u>
# Ниже видоизмененный кусочек из Dashbord Canvas для издательства, где работала.
#
# ![Canvas.jpg](attachment:07e9023e-ba80-4c23-a55d-a6a600c9ee54.jpg)

# %% [markdown]
# #### <u>2. Проверять данные, которые использую:</u>
# - смотреть глазами
# - строить запросы в различных разрезах
# -  отвечать на вопрос - верны ли данные, и почему

# %% [markdown]
# #### <u>3. Строить чарты для оценки базовых метрик:</u>
#
# - Абсолютные показатели (например, DAU)
# - Нормированные показатели (например, CTR)
# - Топ важных событий
#
# ![dau.jpg](attachment:09a39482-80b4-4302-862b-822c8bb62c04.jpg)
# ![ctr.jpg](attachment:b838a21c-08e2-4dd4-96e0-48ca8375459e.jpg)
# ![топ-постов.jpg](attachment:1bc0f007-f4b1-4c3b-bb33-c350bf9325a9.jpg)

# %% [markdown]
# #### <u>4. Подбирать верный тип диаграммы</u>
# ######
# ![Source_1.jpg](attachment:f7cd4a81-889f-42e9-9e75-0a4b6b7fff5f.jpg)
# ![Source_2.jpg](attachment:a0af4558-ba3a-450d-8520-4e3ab00e22d3.jpg)

# %% [markdown]
# #### <u>5. Делать визуал, отражающий реальное изменение метрик</u>
# ######
# ![cancel_rate_false_2.jpg](attachment:15a42ed7-cea9-4218-81d7-8e0161816b6f.jpg)
# ![cancel_rate_true_2.jpg](attachment:32f95050-e5ee-417c-a781-a517f16487fa.jpg)

# %% [markdown]
# #### <u>6. Проводить глубокую аналитику с помощью чартов</u>
# - сколько пользователей продолжает работать с нашим продуктом, например, по когортам.
#
# ![retention_1.jpg](attachment:e614647c-5c5e-47af-bab2-d13fb4123820.jpg)
#
# - анализировать постоянных, ушедших и новых пользователей
#
# ![retention_2.jpg](attachment:79f92c5b-5231-414c-9106-cd6ac6b33cbf.jpg)

# %% [markdown]
# #### <u>7. Подбирать цветовое решениe с учетом:</u>
# - концепции Иттена, для лучшего восприятия
# - знания, что нарушение восприятия зелёного является очень частым вариантом (и лучше использовать другие цвета)
# #####
# ![Itten.jpg](attachment:564cb5aa-2bb7-4400-b16f-8476b5c9c434.jpg)

# %% [markdown]
# #### <u>8. И наконец, собирать из базовых чартов информативные, но не перегруженные дашборды</u>
# ######
# ![лента-новостей-основное.jpg](attachment:0615e446-18e8-4972-9d35-255b03ac896d.jpg)

# %% [markdown]
# #### <u>9. Также умею настраивать отправку отчетов в телеграм-бот с помощью Airflow.</u>
# ######
# ![Telegram_bot.jpg](attachment:b99d9cbe-8f91-4468-b6ff-a12a5577f0b3.jpg)
